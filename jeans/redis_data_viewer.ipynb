# %% [markdown]
# # Redis Data Viewer
# This notebook displays all available holiday, air quality, and weather data stored in Redis.

# %%
import redis
import json
from pprint import pprint

# Connect to Redis
r = redis.Redis(host='localhost', port=6379, decode_responses=True)

# %% [markdown]
# ## Holidays

# %%
# Display holidays
holiday_keys = r.keys('holiday:*')
for key in sorted(holiday_keys):
    print(f"{key}: {r.get(key)}")
# Out:
# holiday:2024-01-01: วันขึ้นปีใหม่
# holiday:2024-02-24: วันมาฆบูชา
# holiday:2024-02-26: วันหยุดชดเชย
# holiday:2024-04-06: วันจักรี
# holiday:2024-04-08: วันหยุดชดเชย
# holiday:2024-04-12: วันหยุดพิเศษ (ครม.)
# holiday:2024-04-13: วันสงกรานต์
# holiday:2024-04-14: วันสงกรานต์
# holiday:2024-04-15: วันสงกรานต์
# holiday:2024-04-16: วันหยุดชดเชย
# holiday:2024-05-01: วันแรงงาน (เอกชน)
# holiday:2024-05-04: วันฉัตรมงคล
# holiday:2024-05-06: วันหยุดชดเชย
# holiday:2024-05-10: วันพืชมงคล (ราชการ)
# holiday:2024-05-22: วันวิสาขบูชา
# holiday:2024-06-03: วันเฉลิมฯ พระบรมราชินี
# holiday:2024-07-20: วันอาสาฬหบูชา
# holiday:2024-07-21: วันเข้าพรรษา (ราชการ)
# holiday:2024-07-22: วันหยุดชดเชย
# holiday:2024-07-28: วันเฉลิมฯ พระวชิรเกล้าเจ้าอยู่หัว
# holiday:2024-07-29: วันหยุดชดเชย
# holiday:2024-08-12: วันแม่
# holiday:2024-10-13: วันนวมินทรมหาราช
# holiday:2024-10-14: วันหยุดชดเชย
# holiday:2024-10-23: วันปิยมหาราช
# holiday:2024-12-05: วันพ่อ
# holiday:2024-12-10: วันรัฐธรรมนูญ
# holiday:2024-12-30: วันหยุดพิเศษ (ครม.)
# holiday:2024-12-31: วันสิ้นปี
# holiday:2025-01-01: วันขึ้นปีใหม่
# holiday:2025-02-12: วันมาฆบูชา
# holiday:2025-04-06: วันจักรี
# holiday:2025-04-07: วันหยุดชดเชย
# holiday:2025-04-13: วันสงกรานต์
# holiday:2025-04-14: วันสงกรานต์
# holiday:2025-04-15: วันสงกรานต์
# holiday:2025-04-16: วันหยุดชดเชย
# holiday:2025-05-01: วันแรงงาน (เอกชน)
# holiday:2025-05-04: วันฉัตรมงคล
# holiday:2025-05-05: วันหยุดชดเชย
# holiday:2025-05-09: วันพืชมงคล (ราชการ)
# holiday:2025-05-11: วันวิสาขบูชา
# holiday:2025-05-12: วันหยุดชดเชย
# holiday:2025-06-02: วันหยุดพิเศษ (ครม.)
# holiday:2025-06-03: วันเฉลิมฯ พระบรมราชินี
# holiday:2025-07-10: วันอาสาฬหบูชา
# holiday:2025-07-11: วันเข้าพรรษา (ราชการ)
# holiday:2025-07-28: วันเฉลิมฯ พระวชิรเกล้าเจ้าอยู่หัว
# holiday:2025-08-11: วันหยุดพิเศษ (ครม.)
# holiday:2025-08-12: วันแม่
# holiday:2025-10-13: วันนวมินทรมหาราช
# holiday:2025-10-23: วันปิยมหาราช
# holiday:2025-12-05: วันพ่อ
# holiday:2025-12-10: วันรัฐธรรมนูญ
# holiday:2025-12-31: วันสิ้นปี

# %% [markdown]
# ## Air Quality (PM2.5)

# %%
# Display air quality data
aqi_keys = r.keys('aqi:*')
for key in sorted(aqi_keys):
    print(f"{key}: {r.get(key)}")
# Out:
# aqi:บริษัท คิวมิกซ์ซัพพลาย จำกัด เขตมีนบุรี: 17.5
# aqi:บริษัท ทีพีไอ คอนกรีต จำกัด ถนนรามคำแหง เขตมีนบุรี: 8.7
# aqi:บริษัท ทีพีไอ คอนกรีต จำกัด ถนนสามวา เขตมีนบุรี: 8.1
# aqi:สวน 60 พรรษาสมเด็จพระนางเจ้าพระบรมราชินีนาถ เขตลาดกระบัง: 13.3
# aqi:สวนกีฬารามอินทรา เขตบางเขน: 9.6
# aqi:สวนจตุจักร เขตจตุจักร: 11
# aqi:สวนทวีวนารมย์ เขตทวีวัฒนา: 8.6
# aqi:สวนธนบุรีรมย์ เขตทุ่งครุ: 10.9
# aqi:สวนบางแคภิรมย์ เขตบางแค: 10
# aqi:สวนพระนคร เขตลาดกระบัง: 8.1
# aqi:สวนรมณีย์ทุ่งสีกัน เขตดอนเมือง: 11.6
# aqi:สวนลุมพินี เขตปทุมวัน: 9.1
# aqi:สวนวชิรเบญจทัศ เขตจตุจักร: 9.7
# aqi:สวนสมเด็จพระนางเจ้าสิริกิติ์ฯ เขตจตุจักร: 9.9
# aqi:สวนสันติภาพ เขตราชเทวี: 8.1
# aqi:สวนสาธารณะเฉลิมพระเกียรติ 6 รอบพระชนมพรรษา เขตบางคอแหลม: 9.5
# aqi:สวนหนองจอก เขตหนองจอก: 15.1
# aqi:สวนหลวง ร.9 เขตประเวศ: 8.1
# aqi:สวนหลวงพระราม 8 เขตบางพลัด: 10.1
# aqi:สวนเฉลิมพระเกียรติ 80 พรรษา เขตบางกอกน้อย: 13.3
# aqi:สวนเบญจกิติ เขตคลองเตย: 8.4
# aqi:สวนเสรีไทย เขตบึงกุ่ม: 15.9
# aqi:อุทยานเบญจสิริ (สวนเบญจสิริ) เขตคลองเตย: 10.3
# aqi:เขตคลองสาน: 13.7
# aqi:เขตคลองสามวา: 16.4
# aqi:เขตคลองเตย: 15.7
# aqi:เขตคันนายาว: 9.5
# aqi:เขตจตุจักร: 13.7
# aqi:เขตจอมทอง: 8.2
# aqi:เขตดอนเมือง: 11.9
# aqi:เขตดินแดง: 10.9
# aqi:เขตดินแดง (สถานี คพ.): 16.3
# aqi:เขตดุสิต: 12.1
# aqi:เขตตลิ่งชัน: 10.3
# aqi:เขตทวีวัฒนา: 10.6
# aqi:เขตทุ่งครุ: 13
# aqi:เขตธนบุรี: 13.3
# aqi:เขตธนบุรี (สถานี คพ.): 13.3
# aqi:เขตบางกอกน้อย: 15.3
# aqi:เขตบางกอกใหญ่: 16.5
# aqi:เขตบางกะปิ: 11.6
# aqi:เขตบางขุนเทียน: 14
# aqi:เขตบางขุนเทียน (สถานี คพ.): 13.3
# aqi:เขตบางคอแหลม: 9.9
# aqi:เขตบางซื่อ: 12.6
# aqi:เขตบางนา: 19.5
# aqi:เขตบางบอน: 14.5
# aqi:เขตบางพลัด: 15.8
# aqi:เขตบางรัก: 15.1
# aqi:เขตบางเขน: 10
# aqi:เขตบางแค: 10.9
# aqi:เขตบึงกุ่ม: 6.6
# aqi:เขตปทุมวัน: 17.4
# aqi:เขตปทุมวัน (สถานี คพ.): 14.3
# aqi:เขตประเวศ: 12.7
# aqi:เขตป้อมปราบศัตรูพ่าย: 12.3
# aqi:เขตพญาไท: 13.3
# aqi:เขตพญาไท (สถานี คพ.): 6.6
# aqi:เขตพระนคร: 12.1
# aqi:เขตพระโขนง: 12.1
# aqi:เขตภาษีเจริญ: 8.9
# aqi:เขตมีนบุรี: 13.3
# aqi:เขตยานนาวา: 7.6
# aqi:เขตยานนาวา (สถานี คพ.): 11.8
# aqi:เขตราชเทวี: 20.8
# aqi:เขตราษฎร์บูรณะ: 17.4
# aqi:เขตลาดกระบัง: 18.8
# aqi:เขตลาดพร้าว: 10.3
# aqi:เขตวังทองหลาง: 23
# aqi:เขตวังทองหลาง (สถานี คพ.): 14.8
# aqi:เขตวัฒนา: 13.3
# aqi:เขตสวนหลวง: 9.5
# aqi:เขตสะพานสูง: 8.9
# aqi:เขตสัมพันธวงศ์: 9.5
# aqi:เขตสาทร: 12.5
# aqi:เขตสายไหม: 15.5
# aqi:เขตหนองจอก: 25
# aqi:เขตหนองแขม: 14.3
# aqi:เขตหลักสี่: 10.2
# aqi:เขตห้วยขวาง: 10

# %% [markdown]
# ## Weather Forecasts

# %%
# Display weather data
weather_keys = r.keys('weather:*')
for key in sorted(weather_keys):
    print(f"{key}:")
    try:
        data = json.loads(r.get(key))
        pprint(data)
    except:
        print(r.get(key))
# Out:
# weather:2025-05-08:Bangkok:
# {'date': '2025-05-08',
#  'max_temp': '35',
#  'min_temp': '27',
#  'province': 'Bangkok',
#  'rain': 'Rain 30% of area',
#  'weather': 'Heavy Rain',
#  'wind_speed': '19'}
# weather:2025-05-08:Nakhon Pathom:
# {'date': '2025-05-08',
#  'max_temp': '36',
#  'min_temp': '26',
#  'province': 'Nakhon Pathom',
#  'rain': 'Rain 30% of area',
#  'weather': 'Heavy Rain',
#  'wind_speed': '15'}
# weather:2025-05-08:Nonthaburi:
# {'date': '2025-05-08',
#  'max_temp': '36',
#  'min_temp': '27',
#  'province': 'Nonthaburi',
#  'rain': 'Rain 30% of area',
#  'weather': 'Heavy Rain',
#  'wind_speed': '19'}
# weather:2025-05-08:Pathum Thani:
# {'date': '2025-05-08',
#  'max_temp': '35',
#  'min_temp': '27',
#  'province': 'Pathum Thani',
#  'rain': 'Rain 30% of area',
#  'weather': 'Heavy Rain',
#  'wind_speed': '19'}
# weather:2025-05-08:Samut Prakan:
# {'date': '2025-05-08',
#  'max_temp': '|',
#  'min_temp': '|',
#  'province': 'Samut Prakan',
#  'rain': 'Rain 30% of area',
#  'weather': 'Heavy Rain',
#  'wind_speed': '17'}
# weather:2025-05-08:Samut Sakhon:
# {'date': '2025-05-08',
#  'max_temp': '|',
#  'min_temp': '|',
#  'province': 'Samut Sakhon',
#  'rain': 'Rain 30% of area',
#  'weather': 'Heavy Rain',
#  'wind_speed': '17'}
# weather:2025-05-09:Bangkok:
# {'date': '2025-05-09',
#  'max_temp': '37',
#  'min_temp': '28',
#  'province': 'Bangkok',
#  'rain': 'Rain 20% of area',
#  'weather': 'Heavy Rain',
#  'wind_speed': '20'}
# weather:2025-05-09:Nakhon Pathom:
# {'date': '2025-05-09',
#  'max_temp': '38',
#  'min_temp': '27',
#  'province': 'Nakhon Pathom',
#  'rain': 'Rain 20% of area',
#  'weather': 'Heavy Rain',
#  'wind_speed': '19'}
# weather:2025-05-09:Nonthaburi:
# {'date': '2025-05-09',
#  'max_temp': '38',
#  'min_temp': '28',
#  'province': 'Nonthaburi',
#  'rain': 'Rain 20% of area',
#  'weather': 'Heavy Rain',
#  'wind_speed': '19'}
# weather:2025-05-09:Pathum Thani:
# {'date': '2025-05-09',
#  'max_temp': '37',
#  'min_temp': '28',
#  'province': 'Pathum Thani',
#  'rain': 'Rain 20% of area',
#  'weather': 'Heavy Rain',
#  'wind_speed': '20'}
# weather:2025-05-09:Samut Prakan:
# {'date': '2025-05-09',
#  'max_temp': '|',
#  'min_temp': '|',
#  'province': 'Samut Prakan',
#  'rain': 'Rain 20% of area',
#  'weather': 'Heavy Rain',
#  'wind_speed': '19'}
# weather:2025-05-09:Samut Sakhon:
# {'date': '2025-05-09',
#  'max_temp': '|',
#  'min_temp': '|',
#  'province': 'Samut Sakhon',
#  'rain': 'Rain 20% of area',
#  'weather': 'Heavy Rain',
#  'wind_speed': '17'}
# weather:2025-05-10:Bangkok:
# {'date': '2025-05-10',
#  'max_temp': '36',
#  'min_temp': '28',
#  'province': 'Bangkok',
#  'rain': 'Rain 40% of area',
#  'weather': 'Thunder Storm',
#  'wind_speed': '17'}
# weather:2025-05-10:Nakhon Pathom:
# {'date': '2025-05-10',
#  'max_temp': '37',
#  'min_temp': '27',
#  'province': 'Nakhon Pathom',
#  'rain': 'Rain 40% of area',
#  'weather': 'Thunder Storm',
#  'wind_speed': '19'}
# weather:2025-05-10:Nonthaburi:
# {'date': '2025-05-10',
#  'max_temp': '37',
#  'min_temp': '28',
#  'province': 'Nonthaburi',
#  'rain': 'Rain 40% of area',
#  'weather': 'Thunder Storm',
#  'wind_speed': '17'}
# weather:2025-05-10:Pathum Thani:
# {'date': '2025-05-10',
#  'max_temp': '36',
#  'min_temp': '28',
#  'province': 'Pathum Thani',
#  'rain': 'Rain 40% of area',
#  'weather': 'Thunder Storm',
#  'wind_speed': '20'}
# weather:2025-05-10:Samut Prakan:
# {'date': '2025-05-10',
#  'max_temp': '|',
#  'min_temp': '|',
#  'province': 'Samut Prakan',
#  'rain': 'Rain 40% of area',
#  'weather': 'Thunder Storm',
#  'wind_speed': '15'}
# weather:2025-05-10:Samut Sakhon:
# {'date': '2025-05-10',
#  'max_temp': '|',
#  'min_temp': '|',
#  'province': 'Samut Sakhon',
#  'rain': 'Rain 40% of area',
#  'weather': 'Thunder Storm',
#  'wind_speed': '17'}
# weather:2025-05-11:Bangkok:
# {'date': '2025-05-11',
#  'max_temp': '34',
#  'min_temp': '27',
#  'province': 'Bangkok',
#  'rain': 'Rain 60% of area',
#  'weather': 'Thunder Storm',
#  'wind_speed': '17'}
# weather:2025-05-11:Nakhon Pathom:
# {'date': '2025-05-11',
#  'max_temp': '35',
#  'min_temp': '26',
#  'province': 'Nakhon Pathom',
#  'rain': 'Rain 60% of area',
#  'weather': 'Thunder Storm',
#  'wind_speed': '11'}
# weather:2025-05-11:Nonthaburi:
# {'date': '2025-05-11',
#  'max_temp': '35',
#  'min_temp': '27',
#  'province': 'Nonthaburi',
#  'rain': 'Rain 60% of area',
#  'weather': 'Thunder Storm',
#  'wind_speed': '19'}
# weather:2025-05-11:Pathum Thani:
# {'date': '2025-05-11',
#  'max_temp': '34',
#  'min_temp': '27',
#  'province': 'Pathum Thani',
#  'rain': 'Rain 60% of area',
#  'weather': 'Thunder Storm',
#  'wind_speed': '13'}
# weather:2025-05-11:Samut Prakan:
# {'date': '2025-05-11',
#  'max_temp': '|',
#  'min_temp': '|',
#  'province': 'Samut Prakan',
#  'rain': 'Rain 60% of area',
#  'weather': 'Thunder Storm',
#  'wind_speed': '17'}
# weather:2025-05-11:Samut Sakhon:
# {'date': '2025-05-11',
#  'max_temp': '|',
#  'min_temp': '|',
#  'province': 'Samut Sakhon',
#  'rain': 'Rain 60% of area',
#  'weather': 'Thunder Storm',
#  'wind_speed': '15'}
# weather:2025-05-12:Bangkok:
# {'date': '2025-05-12',
#  'max_temp': '33',
#  'min_temp': '26',
#  'province': 'Bangkok',
#  'rain': 'Rain 70% of area',
#  'weather': 'Thunder Storm',
#  'wind_speed': '9'}
# weather:2025-05-12:Nakhon Pathom:
# {'date': '2025-05-12',
#  'max_temp': '34',
#  'min_temp': '25',
#  'province': 'Nakhon Pathom',
#  'rain': 'Rain 70% of area',
#  'weather': 'Thunder Storm',
#  'wind_speed': '15'}
# weather:2025-05-12:Nonthaburi:
# {'date': '2025-05-12',
#  'max_temp': '34',
#  'min_temp': '26',
#  'province': 'Nonthaburi',
#  'rain': 'Rain 70% of area',
#  'weather': 'Thunder Storm',
#  'wind_speed': '19'}
# weather:2025-05-12:Pathum Thani:
# {'date': '2025-05-12',
#  'max_temp': '33',
#  'min_temp': '26',
#  'province': 'Pathum Thani',
#  'rain': 'Rain 70% of area',
#  'weather': 'Thunder Storm',
#  'wind_speed': '22'}
# weather:2025-05-12:Samut Prakan:
# {'date': '2025-05-12',
#  'max_temp': '|',
#  'min_temp': '|',
#  'province': 'Samut Prakan',
#  'rain': 'Rain 70% of area',
#  'weather': 'Thunder Storm',
#  'wind_speed': '11'}
# weather:2025-05-12:Samut Sakhon:
# {'date': '2025-05-12',
#  'max_temp': '|',
#  'min_temp': '|',
#  'province': 'Samut Sakhon',
#  'rain': 'Rain 70% of area',
#  'weather': 'Thunder Storm',
#  'wind_speed': '13'}
# weather:2025-05-13:Bangkok:
# {'date': '2025-05-13',
#  'max_temp': '34',
#  'min_temp': '26',
#  'province': 'Bangkok',
#  'rain': 'Rain 60% of area',
#  'weather': 'Thunder Storm',
#  'wind_speed': '13'}
# weather:2025-05-13:Nakhon Pathom:
# {'date': '2025-05-13',
#  'max_temp': '35',
#  'min_temp': '25',
#  'province': 'Nakhon Pathom',
#  'rain': 'Rain 60% of area',
#  'weather': 'Thunder Storm',
#  'wind_speed': '15'}
# weather:2025-05-13:Nonthaburi:
# {'date': '2025-05-13',
#  'max_temp': '35',
#  'min_temp': '26',
#  'province': 'Nonthaburi',
#  'rain': 'Rain 60% of area',
#  'weather': 'Thunder Storm',
#  'wind_speed': '13'}
# weather:2025-05-13:Pathum Thani:
# {'date': '2025-05-13',
#  'max_temp': '34',
#  'min_temp': '26',
#  'province': 'Pathum Thani',
#  'rain': 'Rain 60% of area',
#  'weather': 'Thunder Storm',
#  'wind_speed': '15'}
# weather:2025-05-13:Samut Prakan:
# {'date': '2025-05-13',
#  'max_temp': '|',
#  'min_temp': '|',
#  'province': 'Samut Prakan',
#  'rain': 'Rain 60% of area',
#  'weather': 'Thunder Storm',
#  'wind_speed': '15'}
# weather:2025-05-13:Samut Sakhon:
# {'date': '2025-05-13',
#  'max_temp': '|',
#  'min_temp': '|',
#  'province': 'Samut Sakhon',
#  'rain': 'Rain 60% of area',
#  'weather': 'Thunder Storm',
#  'wind_speed': '17'}
# weather:2025-05-14:Bangkok:
# {'date': '2025-05-14',
#  'max_temp': '33',
#  'min_temp': '27',
#  'province': 'Bangkok',
#  'rain': 'Rain 60% of area',
#  'weather': 'Heavy Rain',
#  'wind_speed': '15'}
# weather:2025-05-14:Nakhon Pathom:
# {'date': '2025-05-14',
#  'max_temp': '34',
#  'min_temp': '26',
#  'province': 'Nakhon Pathom',
#  'rain': 'Rain 60% of area',
#  'weather': 'Heavy Rain',
#  'wind_speed': '13'}
# weather:2025-05-14:Nonthaburi:
# {'date': '2025-05-14',
#  'max_temp': '34',
#  'min_temp': '27',
#  'province': 'Nonthaburi',
#  'rain': 'Rain 60% of area',
#  'weather': 'Heavy Rain',
#  'wind_speed': '17'}
# weather:2025-05-14:Pathum Thani:
# {'date': '2025-05-14',
#  'max_temp': '33',
#  'min_temp': '27',
#  'province': 'Pathum Thani',
#  'rain': 'Rain 60% of area',
#  'weather': 'Heavy Rain',
#  'wind_speed': '11'}
# weather:2025-05-14:Samut Prakan:
# {'date': '2025-05-14',
#  'max_temp': '|',
#  'min_temp': '|',
#  'province': 'Samut Prakan',
#  'rain': 'Rain 60% of area',
#  'weather': 'Heavy Rain',
#  'wind_speed': '15'}
# weather:2025-05-14:Samut Sakhon:
# {'date': '2025-05-14',
#  'max_temp': '|',
#  'min_temp': '|',
#  'province': 'Samut Sakhon',
#  'rain': 'Rain 60% of area',
#  'weather': 'Heavy Rain',
#  'wind_speed': '15'}

# %%
# Clear the current database
r.flushdb()

# OR clear all databases
# r.flushall()
# Out:
# True
